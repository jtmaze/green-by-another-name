# %% [markdown]
# #### 1.0 Libraries and directories

# %%
import ee 
#import geemap
import geopandas as gpd
import pandas as pd
import pprint as pp

ee.Authenticate()
ee.Initialize(project='ee-green-by-another-name')

roi_name = 'AKCP_sub1'
level = 'sr' # 1) 'sr': surface reflectance 2) 'toa' for top of atmosphere
resample_res = 30
resample_method = 'bilinear'
n_dates = 100 # Number of observation dates (might be less if there aren't enough footprints)
s2_cloud_threshold = 70 # Cloud probability threshold for Sentinel-2 pixels. 
band_dict = {'Sentinel2_sr': ['B2', #Blue
                             'B3', #Green
                             'B4', #Red
                             'B8'], #NIR
             'LandSat8_sr': ['SR_B2', #Blue
                           'SR_B3', #Green
                           'SR_B4', #Red
                           'SR_B5'], #NIR
            'Sentinel2_toa': ['B2', 
                              'B3',
                              'B4',
                              'B8'],
            'LandSat8_toa': ['B2',
                             'B3',
                             'B4',
                             'B5']
}

image_footprints_path = f'./data/overlap_dates_for_roi/{roi_name}_overlap_dates.shp'
best_image_dates = gpd.read_file(image_footprints_path) 
est_utm = f'EPSG:{best_image_dates.estimate_utm_crs().to_epsg()}' # Have to convert pyproj object into literal string for ee

# %% [markdown]
# #### 2.0 Select target dates

# %%
best_image_dates['date_as_dt'] = pd.to_datetime(best_image_dates['date'])

best_image_dates['date_plus_1d'] = best_image_dates['date_as_dt'] + pd.Timedelta(days=1)
best_image_dates = best_image_dates[0:n_dates]
print(len(best_image_dates))
# Out:
# 23

# %% [markdown]
# #### 3.0 Functions for the export pipeline

# %%
best_image_dates.head(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\jtmaz\anaconda3\envs\gee\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# Cell In[1], line 227, in __DW_OUTPUT_FORMATTER__.<locals>.DataWrangler.formatter(cls, var, **kwargs)
#     225 @classmethod
#     226 def formatter(cls, var, **kwargs):
# --> 227     s = cls(var, **kwargs)
#     228     return s._repr_dw_()
#
# Cell In[1], line 221, in __DW_OUTPUT_FORMATTER__.<locals>.DataWrangler.__init__(self, expr_val)
#     218 self.id = str(uuid.uuid4())
#     219 pandas_df, conversion_method = api["pandas_transport"]["convert_to_pandas"](expr_val)
#     220 tmp_vars[self.id] = {
# --> 221     "converted": pandas_df.copy(deep=False), # create a shallow copy in case a displayed object is mutated in the same cell
#     222     "conversion_method": conversion_method
#     223 }
#
# AttributeError: 'NoneType' object has no attribute 'copy'
#           date  int_sqkm  per_cover  \
# 0   2020-05-23   1016.78      100.0
# 1   2020-06-08   1016.78      100.0
# 2   2020-06-15   1016.78      100.0
# 3   2021-06-18   1016.78      100.0
# 4   2020-07-10   1016.78      100.0
# 5   2023-09-28   1016.78      100.0
# 6   2021-07-20   1016.78      100.0
# 7   2022-07-07   1016.74      100.0
# 8   2020-07-08   1016.47      100.0
# 9   2019-05-14    944.83       93.0
# 10  2020-07-03    942.44       93.0
# 11  2024-06-12    934.00       92.0
# 12  2024-08-06    770.02       76.0
# 13  2019-05-03    367.65       36.0
# 14  2019-06-22    327.29       32.0
# 15  2021-09-24    321.11       32.0
# 16  2024-06-19    317.28       31.0
# 17  2019-05-05    317.28       31.0
# 18  2019-07-08    317.28       31.0
# 19  2023-08-04    317.27       31.0
# 20  2024-07-19    316.54       31.0
# 21  2023-09-14    300.76       30.0
# 22  2020-06-01    292.11       29.0
#
#                                              geometry date_as_dt date_plus_1d
# 0   POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2020-05-23   2020-05-24
# 1   POLYGON ((-149.08333 70.42379, -149.08324 70.4... 2020-06-08   2020-06-09
# 2   POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2020-06-15   2020-06-16
# 3   POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2021-06-18   2021-06-19
# 4   POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2020-07-10   2020-07-11
# 5   POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2023-09-28   2023-09-29
# 6   POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2021-07-20   2021-07-21
# 7   POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2022-07-07   2022-07-08
# 8   POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2020-07-08   2020-07-09
# 9   POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2019-05-14   2019-05-15
# 10  POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2020-07-03   2020-07-04
# 11  POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2024-06-12   2024-06-13
# 12  POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2024-08-06   2024-08-07
# 13  POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2019-05-03   2019-05-04
# 14  POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2019-06-22   2019-06-23
# 15  POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2021-09-24   2021-09-25
# 16  POLYGON ((-149.04775 70.2947, -149.04775 70.29... 2024-06-19   2024-06-20
# 17  POLYGON ((-149.04775 70.2947, -149.04775 70.29... 2019-05-05   2019-05-06
# 18  POLYGON ((-149.04775 70.2947, -149.04775 70.29... 2019-07-08   2019-07-09
# 19  POLYGON ((-149.04775 70.2947, -149.04775 70.29... 2023-08-04   2023-08-05
# 20  POLYGON ((-149.06797 70.29497, -149.0685 70.29... 2024-07-19   2024-07-20
# 21  POLYGON ((-149.71718 70.47463, -149.71538 70.4... 2023-09-14   2023-09-15
# 22  POLYGON ((-149.44122 70.45963, -149.44086 70.4... 2020-06-01   2020-06-02

# %%
######################################
# Misc. helper functions
######################################

def export_cloud_mask(
    mask: ee.Image, 
    polygon: ee.Geometry,
    filename: str,
    scale: int
):
    task = ee.batch.Export.image.toDrive(
        image=mask,
        description=filename,
        folder='test',
        scale=scale,
        region=polygon,
        maxPixels=1e13
    )
    
    task.start()
    print(f"Started export of {filename}")

def convert_gpd_geom_to_ee(geom, est_utm):
        """
        Takes a geopandas geom object and coverts it to an Earth Engine polygon
        """
        if est_utm is None:
            out_crs = 'EPSG:4326'
        else:
            out_crs = est_utm

        coords = list(geom.exterior.coords)
        coords_list = [[x, y] for x, y in coords]
        return ee.Geometry.Polygon(coords_list, proj=out_crs)

def add_1d_to_date(date: str):
        date_plus_1d = pd.to_datetime(date) + pd.Timedelta(days=1)
        date_plus_1d.strftime('%Y-%m-%d') # Earth engine API needs strings
        return date_plus_1d

#########################################
# Part I: Functions to find the Sentinel-2 and Landsat8 image collections
#########################################

def find_col(polygon: ee.Geometry, 
             date: str, 
             level: str, 
             satellite: str):

    date_plus_1d = add_1d_to_date(date)
    
    if level == 'sr' and satellite == 'S2':
        asset_string = 'COPERNICUS/S2_SR_HARMONIZED'
    elif level == 'sr' and satellite == 'LS8':
         asset_string = 'LANDSAT/LC08/C02/T1_L2'
    elif level == 'toa' and satellite == 'LS8':
        asset_string = 'LANDSAT/LC08/C02/T1_TOA'
    elif level == 'toa' and satellite == 'S2':
        asset_string = 'COPERNICUS/S2_HARMONIZED'
    else:
        print(f'ERROR: level arg should be "sr" or "toa" not {level}')
    
    col = (
        ee.ImageCollection(asset_string)
        .filterDate(date, date_plus_1d)
        .filterBounds(polygon)
    )

    if col.size().getInfo() == 0:
        print(f'ERROR: No {satellite} images found for {date} with {asset_string} processing level')
        print("********Sentinel-2 Surface Reflectance only available after 2018**********")
        return None

    return col

#########################################
# Part II: Functions to select bands and rescale numerical values
#########################################

def fetch_rescale_imgs(s2_col: ee.ImageCollection,
                       polygon: ee.Geometry,
                       bands: list,
                       satellite: str):
    """
    Generates a single image mosiac with desired bands
    Rescales the bands to match (0-1) surface reflectance range
    TODO: Is rescaling different for TOA??
    """
        
    img = (s2_col.select(bands)
              .mosaic()
              .clip(polygon))
    
    def rescale_s2(img):
        rescaled_bands = img.divide(10_000)
        return rescaled_bands
    
    def rescale_ls8(img):
         rescaled_bands = img.multiply(0.0000275).add(-0.2)
         return rescaled_bands
    
    if satellite == 'S2':
         out_img = rescale_s2(img)
    elif satellite == 'LS8' and level == 'sr':
        out_img = rescale_ls8(img)
    elif satellite == 'LS8' and level == 'toa':
        out_img = img
    else:
         print('ERROR: specify satellite as S2 or LS8')
    
    return out_img

#########################################
# Part III: Functions to produce individual cloud masks
#########################################
  
def make_s2_cloud_mask(polygon: ee.Geometry,
                       date: str, 
                       s2_col: ee.ImageCollection, 
                       s2_cloud_threshold: int,
                       level: str):
    """
    Produces a binary cloud mask from the Copernicus Cloud Probability 
    For SR data mask cirrus clouds and shaddows with the Sentinel-2 SCL (Scene Classification Layer)
    For TOA data use the Opaque and Cirrus cloud bands 
    """
    date_plus_1d = add_1d_to_date(date)

    s2_cloud_prob_string = 'COPERNICUS/S2_CLOUD_PROBABILITY'
    s2_clouds = (ee.ImageCollection(s2_cloud_prob_string)
                 .filterBounds(polygon)
                 .filterDate(date, date_plus_1d)
                 .mosaic()
                 .clip(polygon))
    
    clouds_binary = s2_clouds.select('probability').gt(s2_cloud_threshold).rename('cl_binary')
    
    # The SCL band is only available in the S2 Surface Reflectance Product!
    if level == 'sr':
        s2_scl = (s2_col.select('SCL')
                .mosaic()
                .clip(polygon))
        
    elif level == 'toa':
        # For TOA product, no SCL band is available, so you need to use the SR asset for these bands
        s2_scl = (
            ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
            .filterDate(date, date_plus_1d)
            .select('SCL')
            .filterBounds(polygon)
            .mosaic()
            .clip(polygon)
        )

    else:
        print("Error: properly specify the level ('sr' or 'toa')")

    #clouds_binary = s2_clouds.select('probability').gt(s2_cloud_threshold).rename('cl_binary')
    s2_shaddow_mask = s2_scl.eq(3).rename('s2_shaddow_mask')
    s2_cirrus_mask = s2_scl.eq(10).rename('s2_cirrus_mask') 
    s2_snow_ice = s2_scl.eq(11).rename('s2_snow_ice_mask')
    s2_full_mask = clouds_binary.Or(s2_shaddow_mask)\
        .Or(s2_cirrus_mask)\
        .Or(s2_snow_ice)\
        .rename('s2_full_mask')

    # Get the stats for each masking band

    cloud_stats = clouds_binary.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=10
    ).getInfo()

    shaddow_stats = s2_shaddow_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=10
    ).getInfo()
    
    cirrus_stats = s2_cirrus_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=10
    ).getInfo()
    
    snow_ice_stats = s2_snow_ice.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=10
    ).getInfo()

    all_masked_stats = s2_full_mask.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=polygon,
            maxPixels=1e13,
            scale=10
    ).getInfo()

    cloud_frac = cloud_stats.get('cl_binary')
    shaddow_frac = shaddow_stats.get('s2_shaddow_mask')
    cirrus_frac = cirrus_stats.get('s2_cirrus_mask')
    snow_ice_frac = snow_ice_stats.get('s2_snow_ice_mask')
    all_masked_frac = all_masked_stats.get('s2_full_mask')

    mask_stats = {
        's2_cloud_frac': cloud_frac,
        's2_shaddow_frac': shaddow_frac,
        's2_cirrus_frac': cirrus_frac,
        's2_snow_ice_frac': snow_ice_frac,
        's2_all_masked_frac': all_masked_frac
    }

    return s2_full_mask, mask_stats

def make_ls8_cloud_mask(polygon: ee.Geometry, 
                        ls8_col: ee.ImageCollection):
    """
    Generates a cloud mask for Landsat 8 images using QA_PIXEL bit flags.
    """

    ls8_qa = (ls8_col
              .select('QA_PIXEL')
              .mosaic()
              .clip(polygon))
    
    # Worth noting that LS8 has the same bitmap for TOA and SR data.
    
    # Define bitmasks for the conditions
    cloud_bit_mask = 1 << 3        # Bit 3: Cloud
    cloud_shadow_bit_mask = 1 << 4  # Bit 4: Cloud Shadow
    snow_bit_mask = 1 << 5         # Bit 5: Snow
    cirrus_bit_mask = 1 << 2       # Bit 2: Cirrus
    # Keeping this out becuase I'm already dialating clouds.
    #dilated_cloud_bit_mask = 1 << 1 # Bit 1: Dilated Cloud 

    # Combine all bitmasks into one
    bitmask = (cloud_bit_mask
               | cloud_shadow_bit_mask
               | snow_bit_mask
               | cirrus_bit_mask)

    # Create the mask where any of the bits are set

    ls8_cloud_mask = ls8_qa.bitwiseAnd(cloud_bit_mask).neq(0).rename('ls8_cloud_mask')
    cloud_shadow_mask = ls8_qa.bitwiseAnd(cloud_shadow_bit_mask).neq(0).rename('ls8_shaddow_mask')
    snow_mask = ls8_qa.bitwiseAnd(snow_bit_mask).neq(0).rename('ls8_snow_ice_mask')
    cirrus_mask = ls8_qa.bitwiseAnd(cirrus_bit_mask).neq(0).rename('ls8_cirrus_mask')

    ls8_full_mask = ls8_qa.bitwiseAnd(bitmask).neq(0)

    cloud_stats = ls8_cloud_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=30
    ).getInfo()

    cloud_shadow_stats = cloud_shadow_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=30
    ).getInfo()

    snow_stats = snow_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=30
    ).getInfo()

    cirrus_stats = cirrus_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=30
    ).getInfo()

    all_masked_stats = ls8_full_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=polygon,
        maxPixels=1e13,
        scale=30
    ).getInfo()

    cloud_frac = cloud_stats.get('ls8_cloud_mask')
    cloud_shadow_frac = cloud_shadow_stats.get('ls8_shaddow_mask')
    snow_frac = snow_stats.get('ls8_snow_ice_mask')
    cirrus_frac = cirrus_stats.get('ls8_cirrus_mask')
    all_masked_frac = all_masked_stats.get('ls8_full_mask')

    mask_stats = {
        'ls8_cloud_frac': cloud_frac,
        'ls8_shaddow_frac': cloud_shadow_frac,
        'ls8_snow_ice_frac': snow_frac,
        'ls8_cirrus_frac': cirrus_frac,
        'ls8_all_masked_frac': all_masked_frac
    }

    return ls8_full_mask, mask_stats

def reduce_mask_resolution(mask: ee.Image, resample_res: int, est_utm: str):
    """
    Reduces the resolution of cloud masks
    Returns a mask, which has been converted to local UTM
    """

    original_crs = mask.projection()
    mask_reproj = mask.reproject(
        crs=est_utm,
        scale=resample_res
    )
    mask_repoj_reduced = mask_reproj.resample('bilinear')

    return mask_repoj_reduced

#########################################
# Part IV: Functions to generate common masks and apply it to images
#########################################

def combine_sieve_dilate_masks(s2_mask, ls8_mask, est_utm, resample_res, geometry):
    size_threshold = 50  # Minimum number of pixels to ignore (sieve out) of the cloud mask
    dilation_radius = 500  # The distance (meters) to dilate the clouds for a more conservative cloud mask.

    # Check that Landsat8 mask is local UTM, 
    # Sentinel-2 mask should already be reprojected by reduce_mask_resolution
    if str(ls8_mask.projection().crs().getInfo()) is not est_utm:
        reproj_mask = ls8_mask.reproject(
            crs=ee.Projection(est_utm),
            scale=resample_res
        )
        ls8_mask = reproj_mask

    # Both cloud masks are local UTM this point
    # Need local UTM for dilation
    #test = s2_mask.add(ls8_mask)
    s2_mask = s2_mask.rename('full_mask')
    ls8_mask = ls8_mask.rename('full_mask')
    combined_mask = s2_mask.Or(ls8_mask)

    
    # Sieve small clusters and dilate the cloud
    connected_pixels = combined_mask.connectedPixelCount(maxSize=1_000, eightConnected=True)
    sieved_mask = combined_mask.updateMask(connected_pixels.gte(size_threshold))
    dilation_kernel = ee.Kernel.circle(radius=dilation_radius, units='meters', normalize=False)
    dilated_mask = sieved_mask.focal_max(kernel=dilation_kernel, iterations=1)

    dilated_mask = dilated_mask.reproject(
        crs='EPSG:4326',
        scale=resample_res
    )

    return dilated_mask

def resample_img_then_mask(img: ee.Image, 
                           satellite: str,
                           common_mask: ee.Image, 
                           est_utm: str, 
                           resample_res: int,
                           resample_method: str):
    """
    Resample the image match the common cloud mask's resolution, then mask the image
    """
    #original_proj = img.projection()
    #original_res = original_proj.nominalScale().getInfo()
    # Will always need to reduce the resolution for masking the Sentinel-2 image
    # Only reduce LS8 resolution if necessary. Unless resample_res > 30m, don't resample LS8
    if satellite == 'S2' or (satellite == 'LS8' and resample_res > 30):
        print(f'Resampling image for {satellite} at {resample_res}')
        reproj = img.reproject(
                crs=ee.Projection(est_utm),
                scale=resample_res
        )

        resamp = (reproj.resample(resample_method) \
                  .reproject(
                      crs='EPSG:4326',
                      scale=resample_res
                  )
        )

        # Both mask and image are now EPSG:4326 with at resample_res
        out_image = resamp.updateMask(common_mask.neq(1))
        #pp.pp(out_image.projection().getInfo())

    else: # Image is already at resample resolution (m) in EPSG:4326
    # Reproject so both have same projection, but don't resample. 
        print(f'Not resampling image for {satellite} at {resample_res}')
        reproj = img.reproject(
            crs=ee.Projection(est_utm),
            scale=resample_res
        )
        out_img = reproj.reproject(
            crs="EPSG:4326",
            scale=resample_res
        )
        out_image = out_img.updateMask(common_mask.neq(1))
        #pp.pp(out_image.projection().getInfo())
    
    return out_image

#########################################
# Part V: Main processsing & export functions
#########################################

def s2_processor(polygon: ee.Geometry, 
                date: str,
                level: str, 
                bands: list, 
                resample_res: int,
                est_utm: str, 
                s2_cloud_threshold: int):
    """
    Function to generate Sentinel-2 images and Mask
    """
    s2_col = find_col(polygon, date, level, satellite='S2')
    if s2_col is None:
        return None
    else: 
        s2_img = fetch_rescale_imgs(s2_col, polygon, bands, satellite='S2')
        s2_cloud_mask, s2_mask_stats = make_s2_cloud_mask(polygon, date, s2_col, s2_cloud_threshold, level)
        s2_cloud_mask = reduce_mask_resolution(s2_cloud_mask, resample_res, est_utm)
        #filename = f"s2_cloud_mask_TOA_{date}"
        #export_cloud_mask(s2_cloud_mask, polygon, filename, 30)

        return s2_img, s2_cloud_mask, s2_mask_stats
    
def ls8_processor(polygon: ee.Geometry, 
                  date: str,
                  level: str, 
                  bands: list,
                  resample_res: int,
                  est_utm):
    """
    Function to generate LandSat8 images and mask
    """
    ls8_col = find_col(polygon, date, level, satellite='LS8')
    if ls8_col is None:
         return None
    else:
        ls8_img = fetch_rescale_imgs(ls8_col, polygon, bands, satellite='LS8')
        ls8_cloud_mask, ls8_mask_stats = make_ls8_cloud_mask(polygon, ls8_col)
        # Don't bother resampling Landsat, if resample resolution = 30 meters
        #filename = f"ls8_cloud_mask_TOA_{date}"
        #export_cloud_mask(ls8_cloud_mask, polygon, filename, 30)

        if resample_res != 30:
            ls8_cloud_mask = reduce_mask_resolution(ls8_cloud_mask, resample_res, est_utm)
            return ls8_img, ls8_cloud_mask
        else:
            return ls8_img, ls8_cloud_mask, ls8_mask_stats
        
def main_processor(footprint: gpd.GeoSeries, 
                   level: str, 
                   band_dict: dict, 
                   resample_res: int, 
                   resample_method: str, 
                   est_utm: str, 
                   s2_cloud_threshold: int):

    polygon = convert_gpd_geom_to_ee(footprint['geometry'], est_utm=None)
    date = footprint['date']

    if level == 'toa':
        ls8_bands_key = 'LandSat8_toa'
        s2_bands_key = 'Sentinel2_toa'
    elif level == 'sr':
        ls8_bands_key = 'LandSat8_sr'
        s2_bands_key = 'Sentinel2_sr'
    else:
        print('Error specify proper level')
    
    s2_output = s2_processor(polygon=polygon,
                                date=date,
                                level=level,
                                bands=band_dict[s2_bands_key],
                                resample_res=resample_res,
                                est_utm=est_utm,
                                s2_cloud_threshold=s2_cloud_threshold
    )
    
    if s2_output is None:
        return None
    else:
        s2_img = s2_output[0]
        s2_cloud_mask = s2_output[1]
        s2_mask_stats = s2_output[2]
    
    
    ls8_img, ls8_cloud_mask, ls8_mask_stats = ls8_processor(polygon=polygon,
                                            date=date,
                                            level=level,
                                            bands=band_dict[ls8_bands_key],
                                            resample_res=resample_res,
                                            est_utm=est_utm)
    
    if s2_img is None or ls8_img is None:
         print(f'Matching images not found on {date}')
    else:
        mask_stats = s2_mask_stats | ls8_mask_stats
        common_mask = combine_sieve_dilate_masks(s2_cloud_mask, ls8_cloud_mask, est_utm, resample_res, polygon)
        common_mask_frac = common_mask.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=polygon,
            maxPixels=1e13,
            scale=resample_res
        ).getInfo()

        print(common_mask_frac)

        mask_stats['common_mask_frac'] = common_mask_frac.get('full_mask')
        mask_stats['date'] = date
        mask_stats['s2_cloud_threshold'] = s2_cloud_threshold
        mask_stats['resample_res'] = resample_res
        
        if common_mask_frac.get('full_mask') < 0.7:
            print(f'Common mask fraction is {common_mask_frac.get('full_mask')} exporting images')
            masked_s2 = resample_img_then_mask(s2_img, 'S2', common_mask, est_utm, resample_res, resample_method)
            masked_ls8 = resample_img_then_mask(ls8_img, 'LS8', common_mask, est_utm, resample_res, resample_method)
            image_exporter(masked_s2, masked_ls8, polygon, footprint, resample_res, resample_method, level)
            #export_cloud_mask(s2_cloud_mask, polygon, f'{roi_name}_{date}_s2cloudmask', resample_res)
            #export_cloud_mask(ls8_cloud_mask, polygon, f'{roi_name}_{date}_ls8cloudmask', resample_res)
        else:
            print(f'SKIPPING POOR IMAGE: common mask fraction is {common_mask_frac.get('full_mask')}')

        return mask_stats
    

def image_exporter(masked_s2: ee.Image, 
                   masked_ls8: ee.Image, 
                   polygon: ee.Geometry, 
                   footprint: gpd.GeoSeries,
                   resample_res: int,
                   resample_method: str,
                   level: str):
    """
    Exports the comonly masked images to Google Drive
    """
    if level == 'toa':
        folder = 'toa_images'
    elif level == 'sr':
        folder = 'sr_images'
    else:
        print('Error specify proper level')

    s2_export = ee.batch.Export.image.toDrive(
         image=masked_s2,
         description=f'Sentinel2-{level}_date_{footprint['date']}_roi_{roi_name}_resampled_{resample_method}{resample_res}',
         fileNamePrefix=f'Sentinel2-{level}_date_{footprint['date']}_roi_{roi_name}_resampled_{resample_method}{resample_res}',
         folder=folder,
         scale=30,
         region=polygon,
         crs='EPSG:4326',
         fileFormat='GeoTIFF',
         maxPixels=1e13
    )

    s2_export.start()
    print('Exporting Sentinel-2')

    ls8_export = ee.batch.Export.image.toDrive(
         image=masked_ls8,
         description=f'Landsat8-{level}_date_{footprint['date']}_roi_{roi_name}_resampled_{resample_method}{resample_res}',
         fileNamePrefix=f'Landsat8-{level}_date_{footprint['date']}_roi_{roi_name}_resampled_{resample_method}{resample_res}',
         folder=folder,
         scale=30,
         region=polygon,
         crs='EPSG:4326',
         fileFormat='GeoTIFF',
         maxPixels=1e13
    )

    ls8_export.start()
    print('Exporting Landsat8')

# %% [markdown]
# #### 4.0 Run the export pipeline for the ROI's date footprints and level

# %%
mask_stats = []
for idx, row in best_image_dates.iterrows():
    print(f'Processing {row['date']}')
    img_mask_stats = main_processor(
        footprint=row,
        level=level,
        band_dict=band_dict,
        resample_res=resample_res,
        resample_method=resample_method,
        est_utm=est_utm,
        s2_cloud_threshold=s2_cloud_threshold
    )
    img_mask_stats['roi'] = roi_name
    mask_stats.append(img_mask_stats)
# Out:
# Processing 2020-05-23
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2020-06-08
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2020-06-15
# {'full_mask': 0.7240012117260655}
# SKIPPING POOR IMAGE: common mask fraction is 0.7240012117260655
# Processing 2021-06-18
# {'full_mask': 0.2713311621398795}
# Common mask fraction is 0.2713311621398795 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2020-07-10
# {'full_mask': 0.0024929513421038216}
# Common mask fraction is 0.0024929513421038216 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2023-09-28
# {'full_mask': 0.2879447783724742}
# Common mask fraction is 0.2879447783724742 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2021-07-20
# {'full_mask': 0}
# Common mask fraction is 0 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2022-07-07
# {'full_mask': 0.9948896282557403}
# SKIPPING POOR IMAGE: common mask fraction is 0.9948896282557403
# Processing 2020-07-08
# {'full_mask': 0.2471365363823779}
# Common mask fraction is 0.2471365363823779 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2019-05-14
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2020-07-03
# {'full_mask': 0.014983006812888302}
# Common mask fraction is 0.014983006812888302 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2024-06-12
# {'full_mask': 0.996575421230162}
# SKIPPING POOR IMAGE: common mask fraction is 0.996575421230162
# Processing 2024-08-06
# {'full_mask': 0.8650837078153853}
# SKIPPING POOR IMAGE: common mask fraction is 0.8650837078153853
# Processing 2019-05-03
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2019-06-22
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2021-09-24
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2024-06-19
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2019-05-05
# {'full_mask': 1}
# SKIPPING POOR IMAGE: common mask fraction is 1
# Processing 2019-07-08
# {'full_mask': 0.034018636259518724}
# Common mask fraction is 0.034018636259518724 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2023-08-04
# {'full_mask': 0.012292310011758175}
# Common mask fraction is 0.012292310011758175 exporting images
# Resampling image for S2 at 30
# Not resampling image for LS8 at 30
# Exporting Sentinel-2
# Exporting Landsat8
# Processing 2024-07-19
# {'full_mask': 0.7124462971164862}
# SKIPPING POOR IMAGE: common mask fraction is 0.7124462971164862
# Processing 2023-09-14
# {'full_mask': 0.9924649493337976}
# SKIPPING POOR IMAGE: common mask fraction is 0.9924649493337976
# Processing 2020-06-01
# {'full_mask': 0.9998793215861016}
# SKIPPING POOR IMAGE: common mask fraction is 0.9998793215861016

# %%
mask_df = pd.DataFrame(mask_stats)
mask_df.to_csv(f'./data/img_cloud_solar_stats/{roi_name}_{level}_mask_stats.csv', index=False)
